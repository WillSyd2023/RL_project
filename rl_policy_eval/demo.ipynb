# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from rl_env.rl_env import BitEnv
from rl_policy_eval import PolicyEvalQL

policy = PolicyEvalQL(env=BitEnv(lambda x: 1/(x+1)))

# %%
policy.trials(
    steps_measure = 20000,
    num_measure = 50,
    time_limit = 1000,
    n_eps = 10,
)
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:49<00:00,  4.96s/it]

# %%
policy.visualise()
